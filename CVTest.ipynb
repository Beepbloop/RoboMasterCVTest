# %%
import cv2 as cv
import cv2
import keras
from matplotlib import pyplot as plt
import os
import pandas as pd

# %%
from matplotlib import pyplot as plt
def showim(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
paths = glob.glob("../../Datas/RoboMaster/positive/*.jpg")

# %%
showim(cv.imread(paths[0]))

# %%
# label = pd.read_csv('~/Datas/KaggleHouse/test.csv')
